# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Colored Scatterplots

# %%
iris = pd.read_csv('iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 48    49            5.3           3.7            1.5           0.2
# 1      2            4.9           3.0            1.4           0.2
# 106  107            4.9           2.5            4.5           1.7
# 99   100            5.7           2.8            4.1           1.3
# 86    87            6.7           3.1            4.7           1.5
#
#              Species
# 48       Iris-setosa
# 1        Iris-setosa
# 106   Iris-virginica
# 99   Iris-versicolor
# 86   Iris-versicolor

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa': 1, 'Iris-virginica':2, 'Iris-versicolor':3})
iris.sample(5)
# Out:
# /tmp/ipykernel_2453/2829892583.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa': 1, 'Iris-virginica':2, 'Iris-versicolor':3})
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 52    53            6.9           3.1            4.9           1.5        3
# 38    39            4.4           3.0            1.3           0.2        1
# 18    19            5.7           3.8            1.7           0.3        1
# 119  120            6.0           2.2            5.0           1.5        2
# 97    98            6.2           2.9            4.3           1.3        3

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='jet', alpha=0.7)
# alpha = opaque-city
plt.xlabel("sepal_length")
plt.ylabel("petal_length")
plt.colorbar()
plt.show()

# %% [markdown]
# # Increasing the Size of the graph

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='summer')
plt.xlabel("sepal_length")
plt.ylabel("petal_length")
plt.colorbar()
plt.show()
