# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("adult.csv", na_values=['?', ' ?'])

# %%
df.head()
# Out:
#    age workclass  fnlwgt     education  education.num marital.status  \
# 0   90       NaN   77053       HS-grad              9        Widowed
# 1   82   Private  132870       HS-grad              9        Widowed
# 2   66       NaN  186061  Some-college             10        Widowed
# 3   54   Private  140359       7th-8th              4       Divorced
# 4   41   Private  264663  Some-college             10      Separated
#
#           occupation   relationship   race     sex  capital.gain  \
# 0                NaN  Not-in-family  White  Female             0
# 1    Exec-managerial  Not-in-family  White  Female             0
# 2                NaN      Unmarried  Black  Female             0
# 3  Machine-op-inspct      Unmarried  White  Female             0
# 4     Prof-specialty      Own-child  White  Female             0
#
#    capital.loss  hours.per.week native.country income
# 0          4356              40  United-States  <=50K
# ...

# %%
df.describe()
# Out:
#                 age        fnlwgt  education.num  capital.gain  capital.loss  \
# count  32561.000000  3.256100e+04   32561.000000  32561.000000  32561.000000
# mean      38.581647  1.897784e+05      10.080679   1077.648844     87.303830
# std       13.640433  1.055500e+05       2.572720   7385.292085    402.960219
# min       17.000000  1.228500e+04       1.000000      0.000000      0.000000
# 25%       28.000000  1.178270e+05       9.000000      0.000000      0.000000
# 50%       37.000000  1.783560e+05      10.000000      0.000000      0.000000
# 75%       48.000000  2.370510e+05      12.000000      0.000000      0.000000
# max       90.000000  1.484705e+06      16.000000  99999.000000   4356.000000
#
#        hours.per.week
# count    32561.000000
# mean        40.437456
# std         12.347429
# min          1.000000
# 25%         40.000000
# 50%         40.000000
# 75%         45.000000
# max         99.000000

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 32561 entries, 0 to 32560
# Data columns (total 15 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   age             32561 non-null  int64
#  1   workclass       30725 non-null  object
#  2   fnlwgt          32561 non-null  int64
#  3   education       32561 non-null  object
#  4   education.num   32561 non-null  int64
#  5   marital.status  32561 non-null  object
#  6   occupation      30718 non-null  object
#  7   relationship    32561 non-null  object
#  8   race            32561 non-null  object
#  9   sex             32561 non-null  object
#  10  capital.gain    32561 non-null  int64
#  11  capital.loss    32561 non-null  int64
#  12  hours.per.week  32561 non-null  int64
#  13  native.country  31978 non-null  object
#  14  income          32561 non-null  object
# dtypes: int64(6), object(9)
# memory usage: 3.7+ MB

# %%
# one more waly to handle the "?" value
df.replace('?', np.nan, inplace=True)
df.replace(' ?', np.nan, inplace=True)

# %%
df
# Out:
#        age workclass  fnlwgt     education  education.num      marital.status  \
# 0       90       NaN   77053       HS-grad              9             Widowed
# 1       82   Private  132870       HS-grad              9             Widowed
# 2       66       NaN  186061  Some-college             10             Widowed
# 3       54   Private  140359       7th-8th              4            Divorced
# 4       41   Private  264663  Some-college             10           Separated
# ...    ...       ...     ...           ...            ...                 ...
# 32556   22   Private  310152  Some-college             10       Never-married
# 32557   27   Private  257302    Assoc-acdm             12  Married-civ-spouse
# 32558   40   Private  154374       HS-grad              9  Married-civ-spouse
# 32559   58   Private  151910       HS-grad              9             Widowed
# 32560   22   Private  201490       HS-grad              9       Never-married
#
# ...

# %%
df.sample(5)
# Out:
#        age         workclass  fnlwgt     education  education.num  \
# 7585    51           Private  254230  Some-college             10
# 1656    48  Self-emp-not-inc  107231     Bachelors             13
# 10245   43         State-gov  134782    Assoc-acdm             12
# 6528    41           Private  176069       HS-grad              9
# 24417   34           Private   69491       HS-grad              9
#
#               marital.status         occupation relationship   race     sex  \
# 7585      Married-civ-spouse    Exec-managerial      Husband  White    Male
# 1656      Married-civ-spouse    Exec-managerial      Husband  White    Male
# 10245  Married-spouse-absent      Other-service    Unmarried  White  Female
# 6528               Separated  Machine-op-inspct    Unmarried  White  Female
# 24417     Married-civ-spouse      Other-service      Husband  White    Male
#
#        capital.gain  capital.loss  hours.per.week native.country income
# ...

# %%
df.isnull().sum()
# Out:
# age                  0
# workclass         1836
# fnlwgt               0
# education            0
# education.num        0
# marital.status       0
# occupation        1843
# relationship         0
# race                 0
# sex                  0
# capital.gain         0
# capital.loss         0
# hours.per.week       0
# native.country     583
# income               0
# dtype: int64

# %%
# making the pandas profiling
# !pip install ydata_Profiling
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 400.8/400.8 kB 11.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.7/296.7 kB 13.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 58.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 679.7/679.7 kB 36.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.4/105.4 kB 6.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.0/72.0 kB 5.7 MB/s eta 0:00:00
# ...

# %%
from ydata_profiling import ProfileReport
profile = ProfileReport(df, title="Pandas Profiling Report", explorative=True)

# %%
profile.to_file('profile')
# Out:
# ...
# Render HTML:   0%|          | 0/1 [00:00<?, ?it/s]
# /usr/local/lib/python3.12/dist-packages/ydata_profiling/profile_report.py:386: UserWarning: Extension  not supported. For now we assume .html was intended. To remove this warning, please use .html or .json.
#   warnings.warn(
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %%
df.duplicated().sum()
# Out:
# np.int64(24)

# %%
df.shape
# Out:
# (32561, 15)

# %%
df.drop_duplicates(inplace=True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# lets drop which ever we dont need
df.drop(columns=['age','fnlwgt', 'education.num', 'capital.gain', 'capital.loss', 'hours.per.week'], inplace=True)

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(df.drop(columns=['income']), df['income'], test_size=0.2, random_state=42)

# %%
x_train.sample(10)
# Out:
#               workclass     education      marital.status        occupation  \
# 17281           Private     Bachelors       Never-married   Protective-serv
# 4035            Private  Some-college       Never-married   Exec-managerial
# 29045           Private    Assoc-acdm       Never-married  Transport-moving
# 7948            Private  Some-college            Divorced    Prof-specialty
# 22304           Private           9th  Married-civ-spouse   Farming-fishing
# 21712           Private          10th  Married-civ-spouse      Craft-repair
# 16677           Private       Masters       Never-married      Adm-clerical
# 13012  Self-emp-not-inc       HS-grad  Married-civ-spouse   Farming-fishing
# 31824               NaN  Some-college  Married-civ-spouse               NaN
# 4790            Private       HS-grad  Married-civ-spouse      Craft-repair
#
#         relationship   race     sex native.country
# 17281  Not-in-family  White  Female  United-States
# ...

# %%
x_test
# Out:
#               workclass     education      marital.status         occupation  \
# 3643            Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 16041               NaN          11th       Never-married                NaN
# 9403            Private  Some-college  Married-civ-spouse  Machine-op-inspct
# 17909      Self-emp-inc     Doctorate  Married-civ-spouse     Prof-specialty
# 5198          Local-gov     Bachelors  Married-civ-spouse     Prof-specialty
# ...                 ...           ...                 ...                ...
# 8213   Self-emp-not-inc  Some-college       Never-married       Craft-repair
# 24638               NaN       HS-grad           Separated                NaN
# 5514            Private       HS-grad       Never-married       Craft-repair
# 29831           Private       1st-4th  Married-civ-spouse      Other-service
# 29055           Private   Prof-school       Never-married    Exec-managerial
#
# ...

# %%
y_train
# Out:
# 32239    <=50K
# 30377    <=50K
# 5455     <=50K
# 19698    <=50K
# 23193    <=50K
#          ...
# 29823    <=50K
# 5390      >50K
# 860       >50K
# 15800    <=50K
# 23667    <=50K
# Name: income, Length: 26029, dtype: object

# %%
y_test
# Out:
# 3643     <=50K
# 16041    <=50K
# 9403      >50K
# 17909     >50K
# 5198      >50K
#          ...
# 8213     <=50K
# 24638    <=50K
# 5514     <=50K
# 29831    <=50K
# 29055     >50K
# Name: income, Length: 6508, dtype: object

# %%
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import OrdinalEncoder, OneHotEncoder
from sklearn.compose import ColumnTransformer

# %%
education_order = [[
    "Preschool",
    "1st-4th",
    "5th-6th",
    "7th-8th",
    "9th",
    "10th",
    "11th",
    "12th",
    "HS-grad",
    "Some-college",
    "Assoc-voc",
    "Assoc-acdm",
    "Bachelors",
    "Masters",
    "Prof-school",
    "Doctorate"
]]

# %%
ordinal_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OrdinalEncoder(categories=education_order))
])

# %%
nominal_pipe = Pipeline([
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('encoder', OneHotEncoder(handle_unknown='ignore'))
])

# %%
preprocessor = ColumnTransformer([
    ('ord', ordinal_pipe, ['education']),
    ('nom', nominal_pipe,
     ['workclass', 'marital.status', 'occupation',
      'relationship', 'race', 'sex', 'native.country'])
], remainder='passthrough')

# %%
from sklearn.linear_model import LogisticRegression

# %%
pipe = Pipeline([
    ('preprocessor', preprocessor),
    ('model', LogisticRegression())
])

# %%
pipe.fit(x_train, y_train)
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/linear_model/_logistic.py:465: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. OF ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Pipeline(steps=[('preprocessor',
#                  ColumnTransformer(remainder='passthrough',
#                                    transformers=[('ord',
#                                                   Pipeline(steps=[('imputer',
#                                                                    SimpleImputer(strategy='most_frequent')),
#                                                                   ('encoder',
# ...

# %%
pipe.named_steps
# Out:
# {'preprocessor': ColumnTransformer(remainder='passthrough',
#                    transformers=[('ord',
#                                   Pipeline(steps=[('imputer',
#                                                    SimpleImputer(strategy='most_frequent')),
#                                                   ('encoder',
#                                                    OrdinalEncoder(categories=[['Preschool',
#                                                                                '1st-4th',
#                                                                                '5th-6th',
#                                                                                '7th-8th',
#                                                                                '9th',
#                                                                                '10th',
#                                                                                '11th',
# ...

# %%
pipe.named_steps['preprocessor']
# Out:
# ColumnTransformer(remainder='passthrough',
#                   transformers=[('ord',
#                                  Pipeline(steps=[('imputer',
#                                                   SimpleImputer(strategy='most_frequent')),
#                                                  ('encoder',
#                                                   OrdinalEncoder(categories=[['Preschool',
#                                                                               '1st-4th',
#                                                                               '5th-6th',
#                                                                               '7th-8th',
#                                                                               '9th',
#                                                                               '10th',
#                                                                               '11th',
# ...

# %%
pipe.named_steps['preprocessor'].named_transformers_['ord']
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder',
#                  OrdinalEncoder(categories=[['Preschool', '1st-4th', '5th-6th',
#                                              '7th-8th', '9th', '10th', '11th',
#                                              '12th', 'HS-grad', 'Some-college',
#                                              'Assoc-voc', 'Assoc-acdm',
#                                              'Bachelors', 'Masters',
#                                              'Prof-school', 'Doctorate']]))])

# %%
pipe.named_steps['preprocessor'].named_transformers_['nom']
# Out:
# Pipeline(steps=[('imputer', SimpleImputer(strategy='most_frequent')),
#                 ('encoder', OneHotEncoder(handle_unknown='ignore'))])
