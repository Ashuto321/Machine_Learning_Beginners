# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# #Colored Scatterplots

# %%
iris = pd.read_csv('iris.csv')
iris.sample(5)
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 103  104            6.3           2.9            5.6           1.8
# 144  145            6.7           3.3            5.7           2.5
# 16    17            5.4           3.9            1.3           0.4
# 68    69            6.2           2.2            4.5           1.5
# 8      9            4.4           2.9            1.4           0.2
#
#              Species
# 103   Iris-virginica
# 144   Iris-virginica
# 16       Iris-setosa
# 68   Iris-versicolor
# 8        Iris-setosa

# %%
iris['Species'] = iris['Species'].replace({'Iris-setosa': 1, 'Iris-virginica':2, 'Iris-versicolor':3})
iris.sample(5)
# Out:
# /tmp/ipykernel_2177/2829892583.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   iris['Species'] = iris['Species'].replace({'Iris-setosa': 1, 'Iris-virginica':2, 'Iris-versicolor':3})
#     Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  Species
# 47  48            4.6           3.2            1.4           0.2        1
# 11  12            4.8           3.4            1.6           0.2        1
# 90  91            5.5           2.6            4.4           1.2        3
# 50  51            7.0           3.2            4.7           1.4        3
# 82  83            5.8           2.7            3.9           1.2        3

# %%
plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='jet', alpha=0.7)
# alpha = opaque-city
plt.xlabel("sepal_length")
plt.ylabel("petal_length")
plt.colorbar()
plt.grid()
plt.show()

# %% [markdown]
# # Increasing the Size of the graph

# %%
plt.figure(figsize=(15,7))

plt.scatter(iris['SepalLengthCm'], iris['PetalLengthCm'], c=iris['Species'], cmap='summer')
plt.xlabel("sepal_length")
plt.ylabel("petal_length")
plt.colorbar()
plt.show()

# %% [markdown]
# # Annotation

# %%
# we will use the batters dataset
batters = pd.read_csv('batter.csv')

# %%
batters.shape
# Out:
# (605, 4)

# %%
batters.head(5)
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
batters.shape
# Out:
# (605, 4)

# %%
sample_df = batters.head(100).sample(25,random_state=5)

# %%
sample_df
# Out:
#            batter  runs        avg  strike_rate
# 66      KH Pandya  1326  22.100000   132.203390
# 32       SE Marsh  2489  39.507937   130.109775
# 46      JP Duminy  2029  39.784314   120.773810
# 28       SA Yadav  2644  29.707865   134.009123
# 74      IK Pathan  1150  21.698113   116.751269
# 23     JC Buttler  2832  39.333333   144.859335
# 10      G Gambhir  4217  31.007353   119.665153
# 20    BB McCullum  2882  27.711538   126.848592
# 17     KA Pollard  3437  28.404959   140.457703
# 35        WP Saha  2427  25.281250   124.397745
# 97  ST Jayasuriya   768  27.428571   134.031414
# 37     MA Agarwal  2335  22.669903   129.506378
# 70       DJ Hooda  1237  20.278689   127.525773
# 40         N Rana  2181  27.961538   130.053667
# 60      SS Tiwary  1494  28.730769   115.724245
# 34      JH Kallis  2427  28.552941   105.936272
# 42  KS Williamson  2105  36.293103   123.315759
# 57       DJ Bravo  1560  22.608696   125.100241
# 12      AM Rahane  4074  30.863636   117.575758
# ...

# %%
# for these kinds of graph only we will amke the fig size bigger
plt.figure(figsize=(15,7))

plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])

for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])


plt.grid()
plt.show()

# %%
# you can name these points
x = [1,2,3,4,5]
y = [5,2,4,2,1]

plt.scatter(x,y)
plt.text(1,5,'first point')
plt.text(2,2,'second point')
plt.text(3,4,'third point')
plt.text(4,2,'fourth point')
plt.text(5,1,'fifth point', fontdict=({'size':12,'color':'yellow'}))
plt.grid()
plt.show()

# %% [markdown]
# # Vertical /Horizontal line to show for the bats man with more and less than 130

# %%
plt.figure(figsize=(15,7))

plt.scatter(sample_df['avg'], sample_df['strike_rate'], s=sample_df['runs'])

# for horizontal line we will write
plt.axhline(135,color='green')

# for vertical line we will write
plt.axvline(25, color='yellow')

# annotate = naming the points
for i in range(sample_df.shape[0]):
  plt.text(sample_df['avg'].values[i], sample_df['strike_rate'].values[i], sample_df['batter'].values[i])

# plt.grid()
plt.xlabel('average')
plt.ylabel('strike_rate')
plt.show()

# %% [markdown]
# # Subplots

# %%
#  a diff way to plot a graph

# %%
batters.head()
# Out:
#       batter  runs        avg  strike_rate
# 0    V Kohli  6634  36.251366   125.977972
# 1   S Dhawan  6244  34.882682   122.840842
# 2  DA Warner  5883  41.429577   136.401577
# 3  RG Sharma  5881  30.314433   126.964594
# 4   SK Raina  5536  32.374269   132.535312

# %%
# for increasing the size
plt.figure(figsize=(15,7))

plt.scatter(batters['avg'], batters['strike_rate'], marker='+', color='orange')
plt.title("scatter_plot_of_batters")
plt.xlabel('average')
plt.ylabel('strike_rate')
plt.show()

# %%
fig, ax = plt.subplots(figsize=(15,7))  #here we called the subplot using plt and got ax and fig as objects

# using object ax we called scatter
ax.scatter(batters['avg'], batters['strike_rate'], marker='+', color='red')
# using the ax object we call set_title()
ax.set_title("scatter_plot_of_batters")
ax.set_xlabel('average')
ax.set_ylabel('strike rate')
fig.show()

# %%
fig, ax = plt.subplots(nrows=2, ncols=1, sharex=True, figsize=(10,6))
# in this we have single figure and 2 axies
# first axis = first graph
ax[0].scatter(batters['avg'], batters['strike_rate'], color='green', marker="+")

# seconf axis = second graph
ax[1].scatter(batters['avg'], batters['runs'], color='yellow', marker="*")


# we can set the first graphs labels
ax[0].set_title("scatter plot avg and strike_rate")
ax[0].set_ylabel("strike_rate")

ax[1].set_title("scatter plot avg and runs")
ax[1].set_ylabel("runs")
# Out:
# Text(0, 0.5, 'runs')

# %% [markdown]
# #3D Plots(Scatter-plot)

# %%
batters
# Out:
#              batter  runs        avg  strike_rate
# 0           V Kohli  6634  36.251366   125.977972
# 1          S Dhawan  6244  34.882682   122.840842
# 2         DA Warner  5883  41.429577   136.401577
# 3         RG Sharma  5881  30.314433   126.964594
# 4          SK Raina  5536  32.374269   132.535312
# ..              ...   ...        ...          ...
# 600         C Nanda     0   0.000000     0.000000
# 601      Akash Deep     0   0.000000     0.000000
# 602         S Ladda     0   0.000000     0.000000
# 603  V Pratap Singh     0   0.000000     0.000000
# 604    S Lamichhane     0   0.000000     0.000000
#
# [605 rows x 4 columns]

# %%
# we will define a figure
fig = plt.figure(figsize=(15,7))

# now we will cretae the projetion
ax = plt.subplot(projection='3d')

ax.scatter( batters['runs'],batters['avg'], batters['strike_rate'], marker="+", color='Red')
ax.set_title("IPL  batsman analysis")
ax.set_xlabel("runs")
ax.set_ylabel("avg")
ax.set_zlabel("strike_rate")
# Out:
# Text(0.5, 0, 'strike_rate')

# %% [markdown]
# #3D Plots(Line-Plots)

# %%
# lets take a dataset
x = [1,2,3]
y = [2,3,7]
z = [200,100,300]
fig = plt.figure(figsize=(15,7))

ax = plt.subplot(projection='3d')


ax.scatter( x,y,z, s=[100,100,100], color = ['green', 'red', 'yellow'])
ax.plot(x,y,z,color='red')

# %% [markdown]
# # 3D- Surface Plots

# %%
x = np.linspace(-10,10,100)
y = np.linspace(-10,10,100)

# %%
xx , yy = np.meshgrid(x,y)

# %%
z = xx**2 + yy**2
z.shape
# Out:
# (100, 100)

# %%
fig = plt.figure(figsize=(15,7))

ax = plt.subplot(projection='3d')

p =ax.plot_surface(xx,yy,z, cmap='viridis')

fig.colorbar(p)

# %%
z  = np.sin(xx)+np.cos(yy)

fig = plt.figure(figsize=(15,7))

ax = plt.subplot(projection='3d')

p = ax.plot_surface(xx,yy,z, cmap='viridis')
fig.colorbar(p)
