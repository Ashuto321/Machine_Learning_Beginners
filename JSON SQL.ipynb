# %%
import pandas as pd

# %%
pd.read_json('file name')

# %% [markdown]
# # taking data from any url

# %%
pd.read_json('your url')

# %% [markdown]
# #  Working with SQL Data

# %% [markdown]
# <h3> You need to download zamp and run the downloaded sql on your local machine </h3>

# %% [markdown]
# <h5> you also need to download one connnector which will help in talking with sql using python which is !pip install mysql.connector </h5>

# %%
# after connection
# pd.read_sql_query(" query", your connector variable name)
